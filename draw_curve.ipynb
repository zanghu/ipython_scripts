# %%
import numpy
from  matplotlib import pyplot
import pylab

x = numpy.linspace(0, 10, 1000)
#print x
y = numpy.sin(x)
z = numpy.cos(x ** 2)

pyplot.figure(figsize=(8, 4))

pyplot.plot(x, y, label='$sin(x)$', color='red', linewidth=2)
pyplot.plot(x, z, 'b--', label='$cos(x^2)$')

pyplot.xlabel('Time(s)')
pyplot.ylabel('Volt')
pyplot.title('Pyplot First Example')
pylab.ylim(-1.2, 1.2)
pyplot.xlim(0., 10.)
pyplot.legend()

pyplot.show()

# %%
from numpy import *
import os
os.chdir('/home/zanghu/ProgramFiles/machinelearninginaction/Ch02/EXTRAS')

from numpy import *
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle


n = 1000 #number of points to create
xcord1 = []; ycord1 = []
xcord2 = []; ycord2 = []
xcord3 = []; ycord3 = []
markers =[]
colors =[]
fw = open('testSet.txt','w')
for i in range(n):
    [r0,r1] = random.standard_normal(2)
    myClass = random.uniform(0,1)
    if (myClass <= 0.16):
        fFlyer = random.uniform(22000, 60000)
        tats = 3 + 1.6*r1
        markers.append(20)
        colors.append(2.1)
        classLabel = 1 #'didntLike'
        xcord1.append(fFlyer); ycord1.append(tats)
    elif ((myClass > 0.16) and (myClass <= 0.33)):
        fFlyer = 6000*r0 + 70000
        tats = 10 + 3*r1 + 2*r0
        markers.append(20)
        colors.append(1.1)
        classLabel = 1 #'didntLike'
        if (tats < 0): tats =0
        if (fFlyer < 0): fFlyer =0
        xcord1.append(fFlyer); ycord1.append(tats)
    elif ((myClass > 0.33) and (myClass <= 0.66)):
        fFlyer = 5000*r0 + 10000
        tats = 3 + 2.8*r1
        markers.append(30)
        colors.append(1.1)
        classLabel = 2 #'smallDoses'
        if (tats < 0): tats =0
        if (fFlyer < 0): fFlyer =0
        xcord2.append(fFlyer); ycord2.append(tats)
    else:
        fFlyer = 10000*r0 + 35000
        tats = 10 + 2.0*r1
        markers.append(50)
        colors.append(0.1)
        classLabel = 3 #'largeDoses'
        if (tats < 0): tats =0
        if (fFlyer < 0): fFlyer =0
        xcord3.append(fFlyer); ycord3.append(tats)    

fw.close()
fig = plt.figure()
ax = fig.add_subplot(111)
#ax.scatter(xcord,ycord, c=colors, s=markers)
type1 = ax.scatter(xcord1, ycord1, s=20, c='red')
type2 = ax.scatter(xcord2, ycord2, s=30, c='green')
type3 = ax.scatter(xcord3, ycord3, s=50, c='blue')
ax.legend([type1, type2, type3], ["Did Not Like", "Liked in Small Doses", "Liked in Large Doses"], loc=2)
ax.axis([-5000,100000,-2,25])
plt.xlabel('Frequent Flyier Miles Earned Per Year')
plt.ylabel('Percentage of Time Spent Playing Video Games')
plt.show()

# %%
import numpy
from  matplotlib import pyplot
import pylab

x = numpy.linspace(0, 10, 1000)
#print x
y = numpy.sin(x)
z = numpy.cos(x ** 2)

pylab.figure(figsize=(8, 4))

pylab.plot(x, y, label='$sin(x)$', color='red', linewidth=2)
pylab.plot(x, z, 'b--', label='$cos(x^2)$')

pylab.xlabel('Time(s)')
pylab.ylabel('Volt')
pylab.title('Pyplot First Example')
pylab.ylim(-1.2, 1.2)
pylab.legend()

pylab.show()

# %%
#first plot with matplotlib
import matplotlib.pyplot as plt
plt.plot([1,3,2,4])
plt.show()
#in order to avoid pollution of global namespace, it is strongly recommended to never import like:
#from <module> import *
 

#simple plot
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0.0,6.0,0.1)
plt.plot(x, [xi**2 for xi in x],label = 'First',linewidth = 4,color = 'black')
plt.plot(x, [xi**2+2 for xi in x],label = 'second',color = 'red')
plt.plot(x, [xi**2+5 for xi in x],label = 'third')
plt.axis([0,7,-1,50])
plt.xlabel(r"$\alpha$",fontsize=20)
plt.ylabel(r'y')
plt.title('simple plot')
plt.legend(loc = 'upper left')
plt.grid(True)
plt.savefig('simple plot.pdf',dpi = 200)
print mpl.rcParams['figure.figsize']       #return 8.0,6.0
print mpl.rcParams['savefig.dpi']          #default to 100              the size of the pic will be 800*600
#print mpl.rcParams['interactive']
plt.show()

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0.0,6.0,0.1)
plt.plot(x, [xi**2 for xi in x],label = 'First',linewidth = 4,color = 'black')   #using color string to specify color
plt.plot(x, [xi**2+2 for xi in x],'r',label = 'second')                          #using abbreviation to specify color
plt.plot(x, [xi**2+5 for xi in x],color = (1,0,1,1),label = 'Third')             #using color tuple to specify color
plt.plot(x, [xi**2+9 for xi in x],color = '#BCD2EE',label = 'Fourth')             #using hex string to specify color
plt.xticks(np.arange(0.0,6.0,2.5))
plt.xlabel(r"$\alpha$",fontsize=20)
plt.ylabel(r'y')
plt.title('simple plot')
plt.legend(loc = 'upper left')
plt.grid(True)
plt.savefig('simple plot.pdf',dpi = 200)
print mpl.rcParams['figure.figsize']       #return 8.0,6.0
print mpl.rcParams['savefig.dpi']          #default to 100              the size of the pic will be 800*600
#print mpl.rcParams['interactive']
plt.show()

import matplotlib.pyplot as plt 
import numpy as np 
dict = {'A': 40, 'B': 70, 'C': 30, 'D': 85} 
for i, key in enumerate(dict): plt.bar(i, dict[key]);
plt.xticks(np.arange(len(dict))+0.4, dict.keys());
plt.yticks(dict.values());
plt.grid(True)
plt.show()

import matplotlib.pyplot as plt 
plt.figure(figsize=(10,10));
x = [4, 9, 21, 55, 30, 18] 
labels = ['Swiss', 'Austria', 'Spain', 'Italy', 'France', 
'Benelux'] 
explode = [0.2, 0.1, 0, 0, 0.1, 0] 
plt.pie(x, labels=labels, explode=explode, autopct='%1.1f%%'); 
plt.show()

import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(12,20)
y = np.random.randn(12,20)
#pylab.xlim(-5., 5.)
#pylab.ylim(-5., 5.)
mark = ['s','o','^','v','>','<','d','p','h','8','+','*']
for i in range(0,12):
    plt.scatter(x[i],y[i],marker = mark[i],color =(np.random.rand(1,3)),s=50,label = str(i+1))
#xmin, xmax = pylab.xlim()
#pylab.xlim(-5., 10.)
#pylab.ylim(-5., 5.)
plt.legend()
plt.show()
# Out:
# (6.0, 4.0)
# 72
# (6.0, 4.0)
# 72

# %%
import pylab
import numpy
import os
import cPickle
from itertools import izip

from rsm_numpy_pro_cd import RSM

os.chdir('/home/zanghu/实验save/rsm/rsm_1115_test/record')
file_list = os.listdir(os.getcwd())

exp_list = []
print file_list
for file_name in file_list:

    f = open(file_name)
    err_list = []
    for line in f:
        l = line.strip('\n').split(': ')
        #print 'len l: %d' % len(l)
        if l[0] == 'Mean squared error':
            err_list.append(eval(l[1]))
    assert len(err_list) == 1000
    #print len(err_list)
    f.close()
    exp_list.append(err_list)
assert len(exp_list) == 7

color_list = ['black', 'blue', 'green', 'cyan', 'yellow', 'red', 'magenta']
name_list = ['b_0.01', 'b_0.1', 'e_0.1', 'e_0.001', 'b_0.0001', 'e_0.01', 'b_0.001']
for err, color, name in zip(exp_list, color_list, name_list):
    x_vector = numpy.linspace(start=1, stop=1000, num=1000)

    pylab.plot(x_vector, err, color=color, linewidth=0.5)

    pylab.xlabel('epoch')
    pylab.ylabel('error')
    pylab.title('CD-1 recon_error '+name)
    pylab.xlim(0., 1000)
    pylab.ylim(0., 0.5)
    pylab.legend()
    pylab.grid() 
    pylab.figure(figsize=(512, 256), dpi=100)
    pylab.show()
#pylab.grid() 
#pylab.figure(figsize=(512, 256), dpi=100)
#pylab.show()
# Out:
# ['record_batch_01', 'record_batch_1', 'record_epoch_1', 'record_epoch_001', 'record_batch_0001', 'record_epoch_01', 'record_batch_001']

# %%
import pylab
import numpy
import os
import cPickle
from itertools import izip

from rsm_numpy_pro_cd import RSM

os.chdir('/home/zanghu/实验save/rsm/rsm_1115_test/record_1')
file_list = os.listdir(os.getcwd())

exp_list = []
print file_list
for file_name in file_list:

    f = open(file_name)
    err_list = []
    for line in f:
        l = line.strip('\n').split(': ')
        #print 'len l: %d' % len(l)
        if l[0] == 'Mean squared error':
            err_list.append(eval(l[1]))
    assert len(err_list) == 1000
    #print len(err_list)
    f.close()
    exp_list.append(err_list)
assert len(exp_list) == 8

color_list = ['black', 'blue', 'green', 'cyan', 'yellow', 'red', 'magenta', (0.5,0.5,0.5)]
name_list = ['b_0.01', 'e_0.0001', 'b_0.1', 'e_0.1', 'e_0.001', 'b_0.0001', 'e_0.01', 'b_0.001']
for err, color, name in zip(exp_list, color_list, name_list):
    x_vector = numpy.linspace(start=1, stop=1000, num=1000)

    pylab.plot(x_vector, err, color=color, linewidth=0.5)

    pylab.xlabel('epoch')
    pylab.ylabel('error')
    pylab.title('CD-1 recon_error '+name)
    pylab.xlim(0., 1000)
    pylab.ylim(0., 0.5)
    pylab.legend()
    pylab.grid() 
    pylab.figure(figsize=(512, 256), dpi=100)
    pylab.show()
#pylab.grid() 
#pylab.figure(figsize=(512, 256), dpi=100)
#pylab.show()
# Out:
# ['record_batch_01', 'record_epoch_0001', 'record_batch_1', 'record_epoch_1', 'record_epoch_001', 'record_batch_0001', 'record_epoch_01', 'record_batch_001']

# %%
import pylab
import numpy
import os
import cPickle
from itertools import izip

from rsm_numpy_pro_cd import RSM

os.chdir('/home/zanghu/实验save/rsm/rsm_1117_test/record')
file_list = os.listdir(os.getcwd())

exp_list = []
print file_list
for file_name in file_list:

    f = open(file_name)
    err_list = []
    for line in f:
        l = line.strip('\n').split('train_recon_error: ')
        #print 'len l: %d' % len(l)
        if l[0] == '	':
            err_list.append(eval(l[1]))
    #assert len(err_list) == 1000
    print len(err_list)
    f.close()
    exp_list.append(err_list)
assert len(exp_list) == 2

color_list = ['blue', 'red', 'green', 'cyan', 'yellow', 'black', 'magenta', (0.5,0.5,0.5)]
name_list = ['lr=0.001', 'lr=0.01']
for err, color, name in zip(exp_list, color_list, name_list):
    x_vector = numpy.linspace(start=0, stop=1000, num=1001)

    pylab.plot(x_vector, err, color=color, linewidth=0.5)

    pylab.xlabel('epoch')
    pylab.ylabel('error')
    pylab.title('CD-1 recon_error '+name)
    pylab.xlim(0., 1000)
    pylab.ylim(0., 0.3)
    pylab.legend()
    pylab.grid() 
    pylab.figure(figsize=(512, 256), dpi=100)
    pylab.show()
#pylab.grid() 
#pylab.figure(figsize=(512, 256), dpi=100)
#pylab.show()
# Out:
# ['record_pyl2_noD_001', 'record_pyl2_noD_01']
# 1001
# 1001

# %%
#使用softmax分类器分别对50维的隐主题空间特征，和2000维的原始特征进行训练，之后再对测试集分类
# logistic_sgd_plus是在theano的logistic_sgd基础上修改得到的
from logistic_sgd_plus import sgd_optimization_mnist
import scipy
import cPickle
import numpy
import theano
import theano.tensor as T

#读取下层权值
f = open('/home/zanghu/实验save/rsm/rsm/rsm_result1.pkl')
rsm = cPickle.load(f)
f.close()

W = rsm['w_vh']
b = rsm['w_v']
c = rsm['w_h']

print W.shape
print b.shape
print c.shape

def sigmoid(X):
    return (1. + scipy.tanh(X/2.))/2.


if __name__ == '__main__':
    f = open('/home/zanghu/实验save/rsm/20news_train.npy')
    X_train = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_test.npy')
    X_test = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_train_label.npy')
    y_train = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_test_label.npy')
    y_test = numpy.load(f)
    f.close()
    
    v = X_train
    D = numpy.sum(a=v, axis=1) # 由于使用词袋模型，因此每个文档的词向量的所有分量之和等于该文档的总词数
    sigmoid_activation = numpy.dot(v, W)+ numpy.outer(D, c)
    h_mean = sigmoid(sigmoid_activation)
    X_train = h_mean
    
    v = X_test
    D = numpy.sum(a=v, axis=1) # 由于使用词袋模型，因此每个文档的词向量的所有分量之和等于该文档的总词数
    sigmoid_activation = numpy.dot(v, W)+ numpy.outer(D, c)
    h_mean = sigmoid(sigmoid_activation)
    X_test = h_mean
    
    #print type(design_matrix_train)
    #print design_matrix_train.shape
    
    X_train = theano.shared(numpy.asarray(X_train, dtype=theano.config.floatX), borrow=True)
    y_train = theano.shared(numpy.asarray(y_train, dtype='int32'), borrow=True)
    X_test = theano.shared(numpy.asarray(X_test, dtype=theano.config.floatX), borrow=True)
    y_test = theano.shared(numpy.asarray(y_test, dtype='int32'), borrow=True)
    
    sgd_optimization_mnist(dataset=[(X_train, y_train), (X_test, y_test), (X_test, y_test)], n_in=50, n_out=20)
# Out:
# (2000, 50)
# (2000,)
# (50,)
# ... building the model
# ... training the model
# epoch 1, minibatch 112/112, validation error 95.813333 %
#      epoch 1, minibatch 112/112, test error of best model 95.813333 %
# epoch 2, minibatch 112/112, validation error 90.693333 %
#      epoch 2, minibatch 112/112, test error of best model 90.693333 %
# epoch 3, minibatch 112/112, validation error 81.373333 %
#      epoch 3, minibatch 112/112, test error of best model 81.373333 %
# epoch 4, minibatch 112/112, validation error 72.893333 %
#      epoch 4, minibatch 112/112, test error of best model 72.893333 %
# epoch 5, minibatch 112/112, validation error 67.826667 %
#      epoch 5, minibatch 112/112, test error of best model 67.826667 %
# epoch 6, minibatch 112/112, validation error 64.093333 %
#      epoch 6, minibatch 112/112, test error of best model 64.093333 %
# epoch 7, minibatch 112/112, validation error 61.066667 %
#      epoch 7, minibatch 112/112, test error of best model 61.066667 %
# ...

# %%
from logistic_sgd_plus import sgd_optimization_mnist
import scipy
import cPickle
import numpy
import theano
import theano.tensor as T

#读取下层权值
f = open('/home/zanghu/实验save/rsm/rsm/rsm_result.pkl')
rsm = cPickle.load(f)
f.close()

W = rsm['w_vh']
b = rsm['w_v']
c = rsm['w_h']

def sigmoid(X):
    return (1. + scipy.tanh(X/2.))/2.


if __name__ == '__main__':
    f = open('/home/zanghu/实验save/rsm/20news_train.npy')
    X_train = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_test.npy')
    X_test = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_train_label.npy')
    y_train = numpy.load(f)
    f.close()
    
    f = open('/home/zanghu/实验save/rsm/20news_test_label.npy')
    y_test = numpy.load(f)
    f.close()
    
    #v = X_train
    #D = numpy.sum(a=v, axis=1) # 由于使用词袋模型，因此每个文档的词向量的所有分量之和等于该文档的总词数
    #sigmoid_activation = numpy.dot(v, W)+ numpy.outer(D, c)
    #h_mean = sigmoid(sigmoid_activation)
    #X_train = h_mean
    
    #v = X_test
    #D = numpy.sum(a=v, axis=1) # 由于使用词袋模型，因此每个文档的词向量的所有分量之和等于该文档的总词数
    #sigmoid_activation = numpy.dot(v, W)+ numpy.outer(D, c)
    #h_mean = sigmoid(sigmoid_activation)
    #X_test = h_mean
    
    #print type(design_matrix_train)
    #print design_matrix_train.shape
    
    X_train = theano.shared(numpy.asarray(X_train, dtype=theano.config.floatX), borrow=True)
    y_train = theano.shared(numpy.asarray(y_train, dtype='int32'), borrow=True)
    X_test = theano.shared(numpy.asarray(X_test, dtype=theano.config.floatX), borrow=True)
    y_test = theano.shared(numpy.asarray(y_test, dtype='int32'), borrow=True)
    
    sgd_optimization_mnist(dataset=[(X_train, y_train), (X_test, y_test), (X_test, y_test)], n_in=2000, n_out=20)
# Out:
# ... building the model
# ... training the model
# epoch 1, minibatch 112/112, validation error 73.000000 %
#      epoch 1, minibatch 112/112, test error of best model 73.000000 %
# epoch 2, minibatch 112/112, validation error 57.173333 %
#      epoch 2, minibatch 112/112, test error of best model 57.173333 %
# epoch 3, minibatch 112/112, validation error 49.400000 %
#      epoch 3, minibatch 112/112, test error of best model 49.400000 %
# epoch 4, minibatch 112/112, validation error 44.520000 %
#      epoch 4, minibatch 112/112, test error of best model 44.520000 %
# epoch 5, minibatch 112/112, validation error 41.453333 %
#      epoch 5, minibatch 112/112, test error of best model 41.453333 %
# epoch 6, minibatch 112/112, validation error 39.213333 %
#      epoch 6, minibatch 112/112, test error of best model 39.213333 %
# epoch 7, minibatch 112/112, validation error 37.773333 %
#      epoch 7, minibatch 112/112, test error of best model 37.773333 %
# ...

# %%
import numpy
from  matplotlib import pyplot
import pylab

f = open('mean_precision_matrix.npy')
p_vector = numpy.load(f)
f.close()

f = open('mean_recall_matrix.npy')
r_vector = numpy.load(f)
f.close()

p_vector = p_vector * 100.
r_vector = r_vector #** (1./6.)

#x = numpy.linspace(0, 10, 1000)
#print x
#y = numpy.sin(x)
#z = numpy.cos(x ** 2)

pylab.figure(figsize=(8, 8))
pylab.grid()
pylab.plot(r_vector, p_vector, label='$r-p curve$', color='blue', linewidth=2)
#pylab.plot(x, z, 'b--', label='$cos(x^2)$')

pylab.xlabel('recall(%)')
pylab.ylabel('precision(%)')
pylab.title('20-newsgroups')
#pylab.xlim(0., 1)
pylab.ylim(0., 60)
pylab.legend()

pylab.show()

# %%
#PCA实验，提取不同数量的主成分，之后进行复原（使用pca_view_converter)，之后可视化观察效果
from pylearn2.datasets.mnist import MNIST
#from pylearn2.pca import Cov, CovEigPCA
from preprocessing import PCA
from news20 import News20
import numpy
import pylab

num_topics = 50
dsm = MNIST(which_set='train', start=0, stop=1000)
X = dsm.X
#for i in xrange(10):
#    for j in xrange(10):
#        pylab.subplot(10, 10, i*10+j+1); pylab.axis('off'); pylab.imshow(X[i*10+j].reshape(28, 28), cmap=cm.gray)
#pylab.show()

features = 784
pca = PCA(num_components=50)
pca.apply(dsm, can_fit=True)
X = dsm.X
print X.shape
print pca._pca.component_cutoff.get_value()
print pca._pca.num_components
#supply_matrix = numpy.zeros(shape=(X.shape[0], features-dsm.X.shape[1]))
#dsm.X = numpy.concatenate((dsm.X, supply_matrix), axis=1)
X = dsm.view_converter.design_mat_to_topo_view(dsm.X)
print X.shape
for i in xrange(10):
   for j in xrange(10):
       pylab.subplot(10, 10, i*10+j+1); pylab.axis('off'); pylab.imshow(X[i*10+j].reshape(28, 28), cmap=cm.gray)
pylab.show()
# Out:
# original variance: 51.5891
# processed variance: 43.5115400814
# (1000, 50)
# 50
# 50
# (1000, 28, 28, 1)

# %%
#从20news数据集中提取前50个个主成分
from news20 import News20
from preprocessing import PCA
from news20 import News20
import numpy
import pylab

num_topics=50
ds20_train = News20(which_set='train')
ds20_test  = News20(which_set='test')
pca_train = PCA(num_components=num_topics)
pca_train.apply(ds20_train, can_fit=True)
pca_test = PCA(num_components=num_topics)
pca_test.apply(ds20_test, can_fit=True)
print ds20_train.X.shape
print ds20_test.X.shape

numpy.save('ds20_train_pca50.npy', ds20_train.X)
numpy.save('ds20_test_pca50.npy', ds20_test.X)
print 'save finished...'
# Out:
# original variance: 510.820681642
# processed variance: 333.683035485
# original variance: 436.152141255
# processed variance: 287.484331693
# (11269, 50)
# (7505, 50)

# %%
numpy.save('ds20_train_pca50.npy', ds20_train.X)
numpy.save('ds20_test_pca50.npy', ds20_test.X)
